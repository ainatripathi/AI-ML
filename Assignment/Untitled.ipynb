# %%
pip install scikit-learn
# Out:
# ...
#    ---------------------------------------- 0.0/8.3 MB ? eta -:--:--
#    - -------------------------------------- 0.3/8.3 MB ? eta -:--:--
#    ----- ---------------------------------- 1.0/8.3 MB 3.7 MB/s eta 0:00:02
#    -------- ------------------------------- 1.8/8.3 MB 3.6 MB/s eta 0:00:02
#    ------------- -------------------------- 2.9/8.3 MB 4.0 MB/s eta 0:00:02
#    ------------------ --------------------- 3.9/8.3 MB 4.4 MB/s eta 0:00:02
#    ------------------------- -------------- 5.2/8.3 MB 4.5 MB/s eta 0:00:01
#    ------------------------------ --------- 6.3/8.3 MB 4.7 MB/s eta 0:00:01
#    ----------------------------------- ---- 7.3/8.3 MB 4.7 MB/s eta 0:00:01
#    ---------------------------------------  8.1/8.3 MB 4.6 MB/s eta 0:00:01
#    ---------------------------------------- 8.3/8.3 MB 4.2 MB/s  0:00:02
# ...
#    ---------------------------------------- 0.0/37.3 MB ? eta -:--:--
#    - -------------------------------------- 1.0/37.3 MB 5.2 MB/s eta 0:00:08
# ...

# %%
pip install matplotlib
# Out:
# ...
#    ---------------------------------------- 0.0/8.3 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.3 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.3 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.3 MB ? eta -:--:--
#    - -------------------------------------- 0.3/8.3 MB ? eta -:--:--
#    - -------------------------------------- 0.3/8.3 MB ? eta -:--:--
#    - -------------------------------------- 0.3/8.3 MB ? eta -:--:--
#    -- ------------------------------------- 0.5/8.3 MB 355.8 kB/s eta 0:00:22
#    -- ------------------------------------- 0.5/8.3 MB 355.8 kB/s eta 0:00:22
#    -- ------------------------------------- 0.5/8.3 MB 355.8 kB/s eta 0:00:22
#    -- ------------------------------------- 0.5/8.3 MB 355.8 kB/s eta 0:00:22
#    --- ------------------------------------ 0.8/8.3 MB 357.0 kB/s eta 0:00:22
#    --- ------------------------------------ 0.8/8.3 MB 357.0 kB/s eta 0:00:22
# ...

# %%
import matplotlib.pyplot as plt

# %%
hours=np.array([1,2,3,4,5]).reshape(-1,1)
marks=np.array([30,40,50,60,70])
plt.scatter(marks,hours)

# %%
import numpy as np

# %%
from sklearn.linear_model import LinearRegression
lor=LinearRegression()
lor.fit(hours,marks)
# Out:
# LinearRegression()

# %%
m=lor.coef_[0]
b=lor.intercept_
print(m,b)
# Out:
# 9.999999999999998 20.000000000000007

# %%
pred=lor.predict(hours)
pred_6=lor.predict([[6]])

# %%
print(hours)
print(marks)
print(pred)
# Out:
# [[1]
#  [2]
#  [3]
#  [4]
#  [5]]
# [30 40 50 60 70]
# [30. 40. 50. 60. 70.]

# %%
plt.scatter(hours,marks)
plt.plot(hours,pred)
plt.xlabel("Hours")
plt.ylabel("Marks")
plt.title("Linear Regression")
plt.show()
print("Prediction: ",pred_6[0])
# Out:
# Prediction:  80.0

# %%
cost=np.array([10,20,30,40,50]).reshape(-1,1)
sales=np.array([100,150,200,250,300])

# %%
from sklearn.linear_model import LinearRegression
lor=LinearRegression()
lor.fit(cost,sales)
# Out:
# LinearRegression()

# %%
m=lor.coef_[0]
b=lor.intercept_

# %%
pred=lor.predict(cost)
pred_60=lor.predict([[60]])

# %%
plt.scatter(cost,sales)
plt.plot(cost,pred)
print("Prediction: ",pred_60)
# Out:
# Prediction:  [350.]
